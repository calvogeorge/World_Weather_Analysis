# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from datetime import datetime

#import the API key
from config import weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #if the city is unique, then we will add it to the cities list
    
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 785

# %%
# URL for making weather API calls

#bostonurl = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1862119dd180d0c86b1fc0feeebeb43f&q=Boston"
#bostondic = requests.get(bostonurl).json()

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop througgh all the cities in hte list

for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city
    city_url= url +'&q='+ city.replace(" ","+")
    
    # log the URL, record, and set numbers and the city
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add  to tge record count
    record_count +=1
    
# Run an API request for each of the cities.

    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_weather_desc = city_weather['weather'][0]["description"]
        city_country = city_weather['sys']['country']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_weather_desc,
                          "Country": city_country,
                          "Date": city_date})
                
                
# if an error is experienced, skip the city
    except:
        print('City not found, Skipping...')
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | geraldton
# Processing Record 3 of Set 1 | dikson
# Processing Record 4 of Set 1 | skagastrond
# City not found, Skipping...
# Processing Record 5 of Set 1 | la reforma
# Processing Record 6 of Set 1 | marsa matruh
# Processing Record 7 of Set 1 | amahai
# Processing Record 8 of Set 1 | norman wells
# Processing Record 9 of Set 1 | lompoc
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | mineralnyye vody
# Processing Record 12 of Set 1 | talcahuano
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | fortuna
# Processing Record 16 of Set 1 | gazalkent
# Processing Record 17 of Set 1 | kaitangata
# Processing Record 18 of Set 1 | svetlyy
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | gorin
# ...

# %%
len(city_data)
# Out:
# 723

# %%
# convert city data to a pandas data frame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Punta Arenas -53.1500  -70.9167     41.11        75           0
# 1         Geraldton -28.7667  114.6000     54.01        71          75
# 2            Dikson  73.5069   80.5464     31.69        86           1
# 3        La Reforma  25.0833 -108.0500     91.15        62          88
# 4      Marsa Matruh  31.3525   27.2453     73.47        80           0
# 5            Amahai  -3.3333  128.9167     75.76        87          91
# 6      Norman Wells  65.2820 -126.8329     75.06        33         100
# 7            Lompoc  34.6391 -120.4579     95.02        72           9
# 8         Busselton -33.6500  115.3333     49.08        74          99
# 9  Mineralnyye Vody  44.2103   43.1353     68.09        73           4
#
#    Wind Speed Weather Description Country                 Date
# 0       13.80           clear sky      CL  2021-06-20 20:56:41
# ...

# %%
column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Weather Description']
city_data_df = city_data_df[column_order]
city_data_df.head(10)
# Out:
#                City Country                 Date      Lat       Lng  Max Temp  \
# 0      Punta Arenas      CL  2021-06-20 20:56:41 -53.1500  -70.9167     41.11
# 1         Geraldton      AU  2021-06-20 21:00:59 -28.7667  114.6000     54.01
# 2            Dikson      RU  2021-06-20 21:00:59  73.5069   80.5464     31.69
# 3        La Reforma      MX  2021-06-20 21:01:00  25.0833 -108.0500     91.15
# 4      Marsa Matruh      EG  2021-06-20 21:01:00  31.3525   27.2453     73.47
# 5            Amahai      ID  2021-06-20 21:01:00  -3.3333  128.9167     75.76
# 6      Norman Wells      CA  2021-06-20 21:01:01  65.2820 -126.8329     75.06
# 7            Lompoc      US  2021-06-20 21:01:01  34.6391 -120.4579     95.02
# 8         Busselton      AU  2021-06-20 21:01:02 -33.6500  115.3333     49.08
# 9  Mineralnyye Vody      RU  2021-06-20 21:01:02  44.2103   43.1353     68.09
#
#    Humidity  Cloudiness  Wind Speed Weather Description
# ...

# %%
# Create am output csv file
output_data_file = 'WeatherPy_Database.csv'

city_data_df.to_csv(output_data_file, index_label="City_ID")
